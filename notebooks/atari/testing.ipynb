# %%
from pufferlib.vector import make
from pufferlib.pufferl import PuffeRL
from pufferlib.emulation import GymnasiumPufferEnv
from pufferlib.ocean import env_creator

# %%
cp_env = env_creator(name='puffer_cartpole')

# %%
env = cp_env(seed=0)

# %%
obs, rewards, terminals, truncations, infos = env.step(actions=0)

# %%
obs
# Out:
# array([[ 0.        , -0.19512196,  0.        ,  0.29268292]],
#       dtype=float32)
